# %%
pip install neo4j
# Out:
# Requirement already satisfied: neo4j in /usr/local/lib/python3.6/site-packages (4.0.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/site-packages (from neo4j) (2020.1)
# You are using pip version 10.0.1, however version 20.2b1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from neo4j import GraphDatabase

# %% [markdown]
# ## Connect to the DB

# %% [markdown]
# #### If you don't specify a database name in driver.session, you'll be using the default DB (neo4j)

# %%
uri = "bolt://localhost:7687"

# %%
driver = GraphDatabase.driver(uri, auth=("neo4j", "neo"))

# %%
session = driver.session(database="lsci")

# %% [markdown]
# ## Initialise n10s

# %%
def init_n10s_config(tx):
    result = tx.run("CALL n10s.graphconfig.init({ handleVocabUris : 'IGNORE'})")
    for record in result:
        print(record["param"], record["value"])

# %%
session.write_transaction(init_n10s_config)
# Out:
# handleVocabUris IGNORE
# handleMultival OVERWRITE
# handleRDFTypes LABELS
# keepLangTag False
# multivalPropList None
# keepCustomDataTypes False
# customDataTypePropList None
# applyNeo4jNaming False
# classLabel Class
# subClassOfRel SCO
# dataTypePropertyLabel Property
# objectPropertyLabel Relationship
# subPropertyOfRel SPO
# domainRel DOMAIN
# rangeRel RANGE

# %% [markdown]
# ## Define functions to run SPARQL queries on RDF databases

# %% [markdown]
# SPARQL queries to be run against Wikidata and MeSH dbs

# %%
wikidata_virus_taxon = """PREFIX neo: <neo://voc#>
CONSTRUCT {
 # ?virus a neo:Virus; neo:name ?virusName ;
          neo:HAS_PARENT ?parentVirus ;
          neo:RELATED_FIELD_OF_STUDY ?msAcademicUri ;
          neo:SAME_AS_MESH_DESCRIPTOR ?meshUri .
  # ?parentVirus a neo:Virus .
  }
WHERE {
  # ?virus wdt:P171+ wd:Q808	 ;
          wdt:P171 ?parentVirus;
          rdfs:label ?virusName ;
          filter(lang(?virusName) = "en") .
  
  optional { ?virus wdt:P486 ?meshCode . 
             bind(URI(concat("http://id.nlm.nih.gov/mesh/",?meshCode))  as ?meshUri) }
  optional { ?virus wdt:P6366 ?msAcademic .  
             bind(URI(concat("http://ma-graph.org/entity/",?msAcademic))  as ?msAcademicUri) }
        
} """

# %%
mesh_virus_taxon ="""PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX neo: <neo://voc#>

CONSTRUCT {
# ?s a neo:MeshDescriptor, neo:Virus ; 
     neo:name ?name ;
     neo:HAS_BROADER_DESCRIPTOR ?parentDescriptor .
}
FROM <http://id.nlm.nih.gov/mesh>
WHERE { 
  {
    # ?s meshv:broaderDescriptor* mesh:D014780 #viruses 
  }
  
  # ?s rdfs:label ?name .
  
  optional {
    # ?s meshv:broaderDescriptor ?parentDescriptor .
  }
  
} """

# %%
wikidata_disease_taxon = """PREFIX neo: <neo://voc#>
construct {
  # ?dis a neo:InfectiousDisease ;
     neo:name ?disName ;
     neo:CAUSED_BY ?cause ;
     neo:HAS_PARENT ?parentDisease ;
     neo:RELATED_FIELD_OF_STUDY ?msAcademicUri ;
     neo:SAME_AS_MESH_DESCRIPTOR ?meshUri ;
     neo:SAME_AS_DISEASE_ONTO ?diseaseOntoUri .
}
where { 
  # ?dis wdt:P31/wdt:P279* wd:Q18123741 ;
       rdfs:label ?disName . filter(lang(?disName) = "en")

  optional { ?dis wdt:P828 ?cause }
  optional { ?dis wdt:P279 ?parentDisease .
             # ?parentDisease wdt:P31/wdt:P279* wd:Q18123741 }
  optional { ?dis wdt:P486 ?meshCode . bind(URI(concat("http://id.nlm.nih.gov/mesh/",?meshCode))  as ?meshUri) }
  optional { ?dis wdt:P6366 ?msAcademic .  bind(URI(concat("http://ma-graph.org/entity/",?msAcademic))  as ?msAcademicUri) }
  optional { ?dis wdt:P699 ?diseaseOntoId .  bind(URI(concat("http://purl.obolibrary.org/obo/",REPLACE(?diseaseOntoId, ":", "_")))  as ?diseaseOntoUri) }
} """

# %%
def run_wikidata_query(tx, sparql):
    #print(" Running Wikidata import from SPARQL query: \n" , sparql)
    result = tx.run(" CALL n10s.rdf.import.fetch( "
                    "'https://query.wikidata.org/sparql?query=' + apoc.text.urlencode($sparql), "
                    " 'N-Triples',{ headerParams: { Accept: 'text/plain'}}) "
                    " YIELD terminationStatus, triplesLoaded, triplesParsed, namespaces, extraInfo "
                    " RETURN terminationStatus, triplesLoaded, triplesParsed, extraInfo", sparql=sparql)
    for record in result:
        print("result: ", record["terminationStatus"], 
              ", loadedTriples: ", record["triplesLoaded"], 
              ", parsedTriples: ", record["triplesParsed"], 
              ", extra info: ", record["extraInfo"])

# %%
def run_mesh_query(tx, sparql):
    #print(" Running Wikidata import from SPARQL query: \n" , sparql)
    result = tx.run(" CALL n10s.rdf.import.fetch( "
                    "'https://id.nlm.nih.gov/mesh/sparql?format=TURTLE&query=' + apoc.text.urlencode($sparql), "
                    " 'Turtle') "
                    " YIELD terminationStatus, triplesLoaded, triplesParsed, namespaces, extraInfo "
                    " RETURN terminationStatus, triplesLoaded, triplesParsed, extraInfo", sparql=sparql)
    for record in result:
        print("result: ", record["terminationStatus"], 
              ", loadedTriples: ", record["triplesLoaded"], 
              ", parsedTriples: ", record["triplesParsed"], 
              ", extra info: ", record["extraInfo"])

# %% [markdown]
# ## Run Imports from SPARQL Construct queries

# %%
session.write_transaction(run_wikidata_query, wikidata_virus_taxon)
# Out:
# result:  OK , loadedTriples:  35380 , parsedTriples:  35380 , extra info:

# %%
session.write_transaction(run_mesh_query, mesh_virus_taxon)
# Out:
# result:  OK , loadedTriples:  2308 , parsedTriples:  2308 , extra info:

# %%
session.write_transaction(run_wikidata_query, wikidata_disease_taxon)
# Out:
# result:  OK , loadedTriples:  2972 , parsedTriples:  2972 , extra info:

# %%
mesh_disease_top_level = ['D007239','D009369','D009140','D004066','D009057','D012140','D010038','D009422',
                          'D005128','D052801','D005261','D002318','D006425','D009358','D017437','D009750',
                          'D004700','D007154','D007280','D000820','D013568','D009784','D064419','D014947']

# %%
mesh_disease_taxon = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX neo: <neo://voc#>

CONSTRUCT {{
# ?s a neo:MeshDescriptor, neo:Disease; 
     neo:name ?name ;
     neo:HAS_BROADER_DESCRIPTOR ?parentDescriptor;
     meshv:dateEstablished ?date.
}}
FROM <http://id.nlm.nih.gov/mesh>
WHERE {{ 
  {{
    # ?s meshv:broaderDescriptor* mesh:{id} 
  }}
  
  # ?s rdfs:label ?name ; 
     meshv:dateEstablished ?date .
  
  optional {{
    # ?s meshv:broaderDescriptor ?parentDescriptor .
  }}
  
}} """

# %% [markdown]
# Run multiple SPARQL queries (one per root element id)

# %%
for did in mesh_disease_top_level:
    print("disease id: ", did)
    session.write_transaction(run_mesh_query, mesh_disease_taxon.format( id= did))
# Out:
# disease id:  D007239
# result:  OK , loadedTriples:  4546 , parsedTriples:  4546 , extra info:
# disease id:  D009369
# result:  OK , loadedTriples:  3947 , parsedTriples:  3947 , extra info:
# disease id:  D009140
# result:  OK , loadedTriples:  2261 , parsedTriples:  2261 , extra info:
# disease id:  D004066
# result:  OK , loadedTriples:  1844 , parsedTriples:  1844 , extra info:
# disease id:  D009057
# result:  OK , loadedTriples:  1263 , parsedTriples:  1263 , extra info:
# disease id:  D012140
# result:  OK , loadedTriples:  1434 , parsedTriples:  1434 , extra info:
# disease id:  D010038
# result:  OK , loadedTriples:  760 , parsedTriples:  760 , extra info:
# disease id:  D009422
# result:  OK , loadedTriples:  5725 , parsedTriples:  5725 , extra info:
# disease id:  D005128
# result:  OK , loadedTriples:  1565 , parsedTriples:  1565 , extra info:
# disease id:  D052801
# result:  OK , loadedTriples:  1532 , parsedTriples:  1532 , extra info:
# disease id:  D005261
# result:  OK , loadedTriples:  2258 , parsedTriples:  2258 , extra info:
# disease id:  D002318
# result:  OK , loadedTriples:  2507 , parsedTriples:  2507 , extra info:
# disease id:  D006425
# result:  OK , loadedTriples:  1720 , parsedTriples:  1720 , extra info:
# disease id:  D009358
# result:  OK , loadedTriples:  4696 , parsedTriples:  4696 , extra info:
# disease id:  D017437
# result:  OK , loadedTriples:  2876 , parsedTriples:  2876 , extra info:
# disease id:  D009750
# result:  OK , loadedTriples:  2232 , parsedTriples:  2232 , extra info:
# disease id:  D004700
# result:  OK , loadedTriples:  1052 , parsedTriples:  1052 , extra info:
# disease id:  D007154
# result:  OK , loadedTriples:  1602 , parsedTriples:  1602 , extra info:
# disease id:  D007280
# result:  OK , loadedTriples:  25 , parsedTriples:  25 , extra info:
# disease id:  D000820
# result:  OK , loadedTriples:  983 , parsedTriples:  983 , extra info:
# disease id:  D013568
# result:  OK , loadedTriples:  6052 , parsedTriples:  6052 , extra info:
# disease id:  D009784
# result:  OK , loadedTriples:  156 , parsedTriples:  156 , extra info:
# disease id:  D064419
# result:  OK , loadedTriples:  747 , parsedTriples:  747 , extra info:
# disease id:  D014947
# result:  OK , loadedTriples:  1565 , parsedTriples:  1565 , extra info:

# %% [markdown]
# Run several SPARQL queries, this time driven by the URIs of the `InfectiousDisease` nodes

# %%
def run_wikidata_foreach_disease(tx):
    result = tx.run("""MATCH (id:InfectiousDisease) 
                        WITH id.uri as uri
                        WITH uri, '

                                PREFIX neo: <neo://voc#>
                                construct {
                                  # ?chemCompound a neo:ChemicalCompound ;
                                      neo:USED_FOR_DISEASE ?id;
                                      neo:ACTIVE_INGREDIENT_IN ?pharmaProduct;
                                      neo:SAME_AS_MESH_DESCRIPTOR ?meshUri ;            
                                      neo:name ?chemCompoundName . 

                                  # ?pharmaProduct a neo:PharmaProduct ;
                                     neo:name ?pharmaProductName . 
                                }
                                where { 
                                  bind(<' + uri + '> as ?id)
                                  # ?id wdt:P2176 ?chemCompound .
                                  # ?chemCompound wdt:P31 wd:Q11173 ;
                                       rdfs:label ?chemCompoundName . 
                                       filter(lang(?chemCompoundName) = "en")

                                  optional { ?chemCompound wdt:P486 ?meshCode . 
                                        bind(URI(concat("http://id.nlm.nih.gov/mesh/",?meshCode))  as ?meshUri) }    

                                  optional { ?chemCompound wdt:P3780 ?pharmaProduct.
                                             # ?pharmaProduct rdfs:label ?pharmaProductName . 
                                            filter(lang(?pharmaProductName) = "en")
                                           }
                                }
                        '
                        AS query
                        CALL n10s.rdf.import.fetch(
                          "https://query.wikidata.org/sparql?query=" + apoc.text.urlencode(query),
                          "N-Triples",
                          { headerParams: { Accept: "text/plain"}})
                        YIELD terminationStatus, triplesLoaded, triplesParsed, namespaces, extraInfo
                        RETURN uri, terminationStatus, triplesLoaded, triplesParsed, namespaces, extraInfo""")
    for record in result:
        print("uri", record["uri"], "result: ", record["terminationStatus"], 
              ", loadedTriples: ", record["triplesLoaded"], 
              ", parsedTriples: ", record["triplesParsed"], 
              ", extra info: ", record["extraInfo"])

# %%
session.write_transaction(run_wikidata_foreach_disease)
#this takes a couple of minutes, leave running...
# Out:
# uri http://www.wikidata.org/entity/Q4143044 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55790471 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q220188 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1077505 result:  OK , loadedTriples:  37 , parsedTriples:  37 , extra info:
# uri http://www.wikidata.org/entity/Q749342 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55790457 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q480700 result:  OK , loadedTriples:  39 , parsedTriples:  39 , extra info:
# uri http://www.wikidata.org/entity/Q18554739 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55790462 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q34879 result:  OK , loadedTriples:  396 , parsedTriples:  396 , extra info:
# uri http://www.wikidata.org/entity/Q3718816 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q54911414 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q488207 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55789456 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4845643 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1495085 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1339539 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q683861 result:  OK , loadedTriples:  57 , parsedTriples:  57 , extra info:
# uri http://www.wikidata.org/entity/Q5635621 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55788194 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55789049 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q157661 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55783742 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3643111 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q977090 result:  OK , loadedTriples:  61 , parsedTriples:  61 , extra info:
# uri http://www.wikidata.org/entity/Q223663 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q243257 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4236559 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q8027735 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4065009 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1339986 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55790495 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q9378210 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55790483 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q379054 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q47790 result:  OK , loadedTriples:  31 , parsedTriples:  31 , extra info:
# uri http://www.wikidata.org/entity/Q4243298 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2264130 result:  OK , loadedTriples:  25 , parsedTriples:  25 , extra info:
# uri http://www.wikidata.org/entity/Q18967342 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q639776 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558260 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q738292 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1977562 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18967339 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q842169 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q19000403 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q19000404 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2849596 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q652744 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558249 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7476596 result:  OK , loadedTriples:  28 , parsedTriples:  28 , extra info:
# uri http://www.wikidata.org/entity/Q2583514 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q606895 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55785933 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2558586 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3900761 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558227 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558221 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1476361 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q54926511 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q15975063 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18557366 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q182672 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12856939 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558204 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558202 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558200 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q815753 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2665559 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1779250 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12048208 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q694552 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q14541745 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787741 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787742 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787744 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787745 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2271749 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q55783380 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55782051 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q265420 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q622969 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1760607 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11775289 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2741820 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q19850514 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5548621 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3067401 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q20736850 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q836356 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q8071861 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q54927311 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7440546 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q14541792 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1024563 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1724539 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787780 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q627368 result:  OK , loadedTriples:  29 , parsedTriples:  29 , extra info:
# uri http://www.wikidata.org/entity/Q55788630 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554268 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q19597369 result:  OK , loadedTriples:  364 , parsedTriples:  364 , extra info:
# uri http://www.wikidata.org/entity/Q1737838 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554261 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1597571 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55789952 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4199106 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q28690596 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55785577 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11730777 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55786419 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55786418 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1343674 result:  OK , loadedTriples:  36 , parsedTriples:  36 , extra info:
# uri http://www.wikidata.org/entity/Q18967247 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1928978 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18924547 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3798547 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q17583 result:  OK , loadedTriples:  11 , parsedTriples:  11 , extra info:
# uri http://www.wikidata.org/entity/Q5255922 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2360849 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q1932655 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556883 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q162262 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q665258 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1813747 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11996271 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q3091959 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q184489 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18975727 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q680873 result:  OK , loadedTriples:  14 , parsedTriples:  14 , extra info:
# uri http://www.wikidata.org/entity/Q3824458 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q319315 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2859732 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q725345 result:  OK , loadedTriples:  41 , parsedTriples:  41 , extra info:
# uri http://www.wikidata.org/entity/Q12857334 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554672 result:  OK , loadedTriples:  44 , parsedTriples:  44 , extra info:
# uri http://www.wikidata.org/entity/Q55790545 result:  OK , loadedTriples:  10 , parsedTriples:  10 , extra info:
# uri http://www.wikidata.org/entity/Q11663754 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q821711 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1470140 result:  OK , loadedTriples:  29 , parsedTriples:  29 , extra info:
# uri http://www.wikidata.org/entity/Q2112692 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18553329 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q63472138 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55790522 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q876887 result:  OK , loadedTriples:  134 , parsedTriples:  134 , extra info:
# uri http://www.wikidata.org/entity/Q55790521 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1722736 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q866602 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q2544887 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4226389 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4417986 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2603200 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554637 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5062121 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3540280 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q618032 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55788209 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7808080 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7850856 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3053951 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18975243 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18975234 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554606 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18975687 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2028074 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55788481 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11634308 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7193348 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12856885 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558195 result:  OK , loadedTriples:  59 , parsedTriples:  59 , extra info:
# uri http://www.wikidata.org/entity/Q18558192 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558193 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12201175 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1452495 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1369020 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558175 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7850839 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q890785 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q653078 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18928476 result:  OK , loadedTriples:  13 , parsedTriples:  13 , extra info:
# uri http://www.wikidata.org/entity/Q18558169 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2700304 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558168 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2217862 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558154 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5609817 result:  OK , loadedTriples:  91 , parsedTriples:  91 , extra info:
# uri http://www.wikidata.org/entity/Q18967690 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4364722 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12856836 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q337998 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q727028 result:  OK , loadedTriples:  185 , parsedTriples:  185 , extra info:
# uri http://www.wikidata.org/entity/Q25111181 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1420459 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4118581 result:  OK , loadedTriples:  10 , parsedTriples:  10 , extra info:
# uri http://www.wikidata.org/entity/Q3678510 result:  OK , loadedTriples:  33 , parsedTriples:  33 , extra info:
# uri http://www.wikidata.org/entity/Q30917590 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55783643 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q532158 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55231802 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558118 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558116 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q690032 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q4958833 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558100 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q54959539 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q6946984 result:  OK , loadedTriples:  28 , parsedTriples:  28 , extra info:
# uri http://www.wikidata.org/entity/Q18558102 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q804521 result:  OK , loadedTriples:  62 , parsedTriples:  62 , extra info:
# uri http://www.wikidata.org/entity/Q2886899 result:  OK , loadedTriples:  81 , parsedTriples:  81 , extra info:
# uri http://www.wikidata.org/entity/Q500536 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5265029 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1856914 result:  OK , loadedTriples:  12 , parsedTriples:  12 , extra info:
# uri http://www.wikidata.org/entity/Q304601 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q487837 result:  OK , loadedTriples:  13 , parsedTriples:  13 , extra info:
# uri http://www.wikidata.org/entity/Q1476027 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q567660 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4944687 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q448768 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4366062 result:  OK , loadedTriples:  25 , parsedTriples:  25 , extra info:
# uri http://www.wikidata.org/entity/Q2500965 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q6014862 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787614 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7933588 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1734637 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q28971 result:  OK , loadedTriples:  23 , parsedTriples:  23 , extra info:
# uri http://www.wikidata.org/entity/Q12981943 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1432397 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787600 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q6137239 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554163 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3724806 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4280605 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q25098926 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q64212020 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q734512 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1421272 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3008595 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q744387 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q662016 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q926462 result:  OK , loadedTriples:  66 , parsedTriples:  66 , extra info:
# uri http://www.wikidata.org/entity/Q12656487 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q55789818 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18557641 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1934052 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q182155 result:  OK , loadedTriples:  69 , parsedTriples:  69 , extra info:
# uri http://www.wikidata.org/entity/Q164727 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2059267 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2600216 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7248868 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18553275 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1066011 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4137692 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12125 result:  OK , loadedTriples:  34 , parsedTriples:  34 , extra info:
# uri http://www.wikidata.org/entity/Q18554110 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q666481 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787210 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554585 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q388646 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q18553250 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18553251 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1210303 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5160416 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q10714833 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55790841 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55009178 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q327281 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2845432 result:  OK , loadedTriples:  15 , parsedTriples:  15 , extra info:
# uri http://www.wikidata.org/entity/Q30913569 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55788530 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787208 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18553231 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1416773 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q39222 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q327298 result:  OK , loadedTriples:  12 , parsedTriples:  12 , extra info:
# uri http://www.wikidata.org/entity/Q18553223 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q114085 result:  OK , loadedTriples:  116 , parsedTriples:  116 , extra info:
# uri http://www.wikidata.org/entity/Q3355380 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2475919 result:  OK , loadedTriples:  3 , parsedTriples:  3 , extra info:
# uri http://www.wikidata.org/entity/Q15460254 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q129104 result:  OK , loadedTriples:  90 , parsedTriples:  90 , extra info:
# uri http://www.wikidata.org/entity/Q506652 result:  OK , loadedTriples:  59 , parsedTriples:  59 , extra info:
# uri http://www.wikidata.org/entity/Q12427214 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55789442 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55789443 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18553216 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554548 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12046613 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1227160 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7888578 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q155857 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4577426 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12192 result:  OK , loadedTriples:  181 , parsedTriples:  181 , extra info:
# uri http://www.wikidata.org/entity/Q55790883 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q14565216 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3073142 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q386408 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q14565220 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12195 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2589418 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55790882 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2458539 result:  OK , loadedTriples:  144 , parsedTriples:  144 , extra info:
# uri http://www.wikidata.org/entity/Q11549084 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1897162 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q797668 result:  OK , loadedTriples:  49 , parsedTriples:  49 , extra info:
# uri http://www.wikidata.org/entity/Q55787063 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2012642 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4676975 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q753654 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558072 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3030745 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18967922 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4223496 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3508725 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3382633 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5160454 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5334259 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q103177 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5763722 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1923955 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5532924 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2663527 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q65091887 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2713959 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3776920 result:  OK , loadedTriples:  163 , parsedTriples:  163 , extra info:
# uri http://www.wikidata.org/entity/Q1613885 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q207367 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5743696 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q167264 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q6853 result:  OK , loadedTriples:  62 , parsedTriples:  62 , extra info:
# uri http://www.wikidata.org/entity/Q54945069 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q9430213 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q54912126 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q41788331 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18557164 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18558008 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q10293456 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q614279 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18976020 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7108870 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q481392 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18557138 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q763460 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q184627 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q180266 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2168931 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q36855 result:  OK , loadedTriples:  17 , parsedTriples:  17 , extra info:
# uri http://www.wikidata.org/entity/Q1090290 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q160649 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55082255 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11830340 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q6527832 result:  OK , loadedTriples:  24 , parsedTriples:  24 , extra info:
# uri http://www.wikidata.org/entity/Q55785729 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q443929 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55784897 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2583311 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q780805 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55784898 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q475510 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q650766 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q160653 result:  OK , loadedTriples:  18 , parsedTriples:  18 , extra info:
# uri http://www.wikidata.org/entity/Q5696358 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5090486 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q659584 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q18557581 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4116466 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q10658304 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11775029 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11903425 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11775011 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4678337 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q55782293 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q208726 result:  OK , loadedTriples:  23 , parsedTriples:  23 , extra info:
# uri http://www.wikidata.org/entity/Q247096 result:  OK , loadedTriples:  15 , parsedTriples:  15 , extra info:
# uri http://www.wikidata.org/entity/Q8503890 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18555383 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q76973 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5973989 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q872643 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18557555 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11775031 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q422268 result:  OK , loadedTriples:  27 , parsedTriples:  27 , extra info:
# uri http://www.wikidata.org/entity/Q18556216 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556215 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55779910 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1639227 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556685 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5788570 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55779917 result:  OK , loadedTriples:  10 , parsedTriples:  10 , extra info:
# uri http://www.wikidata.org/entity/Q949694 result:  OK , loadedTriples:  81 , parsedTriples:  81 , extra info:
# uri http://www.wikidata.org/entity/Q55788860 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2528129 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7255052 result:  OK , loadedTriples:  140 , parsedTriples:  140 , extra info:
# uri http://www.wikidata.org/entity/Q11176055 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q767327 result:  OK , loadedTriples:  15 , parsedTriples:  15 , extra info:
# uri http://www.wikidata.org/entity/Q79054860 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q705906 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7900355 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q154865 result:  OK , loadedTriples:  13 , parsedTriples:  13 , extra info:
# uri http://www.wikidata.org/entity/Q154869 result:  OK , loadedTriples:  104 , parsedTriples:  104 , extra info:
# uri http://www.wikidata.org/entity/Q55786242 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1359898 result:  OK , loadedTriples:  11 , parsedTriples:  11 , extra info:
# uri http://www.wikidata.org/entity/Q3907637 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2726043 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q2669284 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2590966 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q154874 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q154878 result:  OK , loadedTriples:  53 , parsedTriples:  53 , extra info:
# uri http://www.wikidata.org/entity/Q55779965 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q963944 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q154882 result:  OK , loadedTriples:  51 , parsedTriples:  51 , extra info:
# uri http://www.wikidata.org/entity/Q2348506 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5849703 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q15951731 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q9333895 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55785373 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55785372 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55785371 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q56237190 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18557951 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55788416 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q681970 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q164655 result:  OK , loadedTriples:  42 , parsedTriples:  42 , extra info:
# uri http://www.wikidata.org/entity/Q3392410 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1122485 result:  OK , loadedTriples:  38 , parsedTriples:  38 , extra info:
# uri http://www.wikidata.org/entity/Q300936 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12090 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q84504375 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# ...
# uri http://www.wikidata.org/entity/Q842428 result:  OK , loadedTriples:  18 , parsedTriples:  18 , extra info:
# uri http://www.wikidata.org/entity/Q18554860 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1909343 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q55783814 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q153356 result:  OK , loadedTriples:  98 , parsedTriples:  98 , extra info:
# uri http://www.wikidata.org/entity/Q18975460 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55789100 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1348374 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5656856 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1048084 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q1346131 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1992236 result:  OK , loadedTriples:  14 , parsedTriples:  14 , extra info:
# uri http://www.wikidata.org/entity/Q4459615 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q18966970 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q134649 result:  OK , loadedTriples:  21 , parsedTriples:  21 , extra info:
# uri http://www.wikidata.org/entity/Q393477 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55009420 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q326663 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q992139 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1637701 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55789146 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q979168 result:  OK , loadedTriples:  33 , parsedTriples:  33 , extra info:
# uri http://www.wikidata.org/entity/Q18553951 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18553953 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3854687 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q3854685 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3508622 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55009402 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q56244339 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1601794 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q44727 result:  OK , loadedTriples:  10 , parsedTriples:  10 , extra info:
# uri http://www.wikidata.org/entity/Q994794 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1883030 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q592804 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q221547 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11679861 result:  OK , loadedTriples:  14 , parsedTriples:  14 , extra info:
# uri http://www.wikidata.org/entity/Q55786913 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55786912 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3832899 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q2046113 result:  OK , loadedTriples:  22 , parsedTriples:  22 , extra info:
# uri http://www.wikidata.org/entity/Q5248726 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q178275 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18553920 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q21774074 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q21774070 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q326638 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556185 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q578994 result:  OK , loadedTriples:  19 , parsedTriples:  19 , extra info:
# uri http://www.wikidata.org/entity/Q5248740 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11876216 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q719656 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q326643 result:  OK , loadedTriples:  37 , parsedTriples:  37 , extra info:
# uri http://www.wikidata.org/entity/Q326648 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55785635 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4316437 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7571853 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q94300555 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q156050 result:  OK , loadedTriples:  40 , parsedTriples:  40 , extra info:
# uri http://www.wikidata.org/entity/Q1347065 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55782116 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556166 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q495202 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18967422 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q337715 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q22350879 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7370337 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556156 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1344812 result:  OK , loadedTriples:  32 , parsedTriples:  32 , extra info:
# uri http://www.wikidata.org/entity/Q55785604 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55785603 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556140 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q428447 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q797128 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q167178 result:  OK , loadedTriples:  21 , parsedTriples:  21 , extra info:
# uri http://www.wikidata.org/entity/Q18555290 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5413808 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q932843 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556139 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3400643 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18355701 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q6007089 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q19000581 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11491562 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q1057333 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q84263196 result:  OK , loadedTriples:  32 , parsedTriples:  32 , extra info:
# uri http://www.wikidata.org/entity/Q12425220 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q12167939 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1194496 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5384031 result:  OK , loadedTriples:  17 , parsedTriples:  17 , extra info:
# uri http://www.wikidata.org/entity/Q55636535 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q51993 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55786985 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3270160 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5274956 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1378675 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4997014 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q101452 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55223519 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18556572 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18555243 result:  OK , loadedTriples:  59 , parsedTriples:  59 , extra info:
# uri http://www.wikidata.org/entity/Q55784380 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q5509169 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q4463309 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787425 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55784390 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3055119 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18557889 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q552330 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q946278 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3100515 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q64875937 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q54931725 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q704930 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q246068 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q18557869 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4138775 result:  OK , loadedTriples:  4 , parsedTriples:  4 , extra info:
# uri http://www.wikidata.org/entity/Q16954986 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1430844 result:  OK , loadedTriples:  11 , parsedTriples:  11 , extra info:
# uri http://www.wikidata.org/entity/Q5458307 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q43987 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55779847 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554338 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q7429850 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q6473911 result:  OK , loadedTriples:  53 , parsedTriples:  53 , extra info:
# uri http://www.wikidata.org/entity/Q809561 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55779873 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55787016 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q1102300 result:  OK , loadedTriples:  7 , parsedTriples:  7 , extra info:
# uri http://www.wikidata.org/entity/Q55787014 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55779876 result:  OK , loadedTriples:  69 , parsedTriples:  69 , extra info:
# uri http://www.wikidata.org/entity/Q55009396 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q4838947 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q89498598 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q8502088 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q777087 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q3624451 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q327005 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q11675828 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18975808 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q55779861 result:  OK , loadedTriples:  172 , parsedTriples:  172 , extra info:
# uri http://www.wikidata.org/entity/Q117394 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:
# uri http://www.wikidata.org/entity/Q18554757 result:  OK , loadedTriples:  0 , parsedTriples:  0 , extra info:

# %%
mesh_chem_top_level = ['D009930','D006571','D011083','D046911','D006730','D045762','D002241',
                       'D008055','D000602','D009706','D045424','D001685','D001697','D004364','D020164']

# %%
mesh_chem_taxon = """PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX meshv: <http://id.nlm.nih.gov/mesh/vocab#>
PREFIX mesh: <http://id.nlm.nih.gov/mesh/>
PREFIX neo: <neo://voc#>

CONSTRUCT {{
# ?s a neo:MeshDescriptor, neo:Disease; 
     neo:name ?name ;
     neo:HAS_BROADER_DESCRIPTOR ?parentDescriptor;
     meshv:PHARMACOLOGICAL_ACTION ?pharmAction ;
     meshv:dateEstablished ?date.
}}
FROM <http://id.nlm.nih.gov/mesh>
WHERE {{ 
  {{
    # ?s meshv:broaderDescriptor* mesh:{id} 
  }}
  
  # ?s rdfs:label ?name ; 
     meshv:dateEstablished ?date .
  
  optional {{
    # ?s meshv:broaderDescriptor ?parentDescriptor .
  }}
  
  optional {{
    # ?s meshv:pharmacologicalAction ?pharmAction .
  }}
  
}} """

# %%
for cid in mesh_chem_top_level:
    print("chem id: ", cid)
    session.write_transaction(run_mesh_query, mesh_chem_taxon.format( id= cid))
# Out:
# chem id:  D009930
# result:  OK , loadedTriples:  10001 , parsedTriples:  10001 , extra info:
# chem id:  D006571
# result:  OK , loadedTriples:  9973 , parsedTriples:  9973 , extra info:
# chem id:  D011083
# result:  OK , loadedTriples:  4577 , parsedTriples:  4577 , extra info:
# chem id:  D046911
# result:  OK , loadedTriples:  2177 , parsedTriples:  2177 , extra info:
# chem id:  D006730
# result:  OK , loadedTriples:  1668 , parsedTriples:  1668 , extra info:
# chem id:  D045762
# result:  OK , loadedTriples:  9855 , parsedTriples:  9855 , extra info:
# chem id:  D002241
# result:  OK , loadedTriples:  5828 , parsedTriples:  5828 , extra info:
# chem id:  D008055
# result:  OK , loadedTriples:  2447 , parsedTriples:  2447 , extra info:
# chem id:  D000602
# result:  OK , loadedTriples:  10001 , parsedTriples:  10001 , extra info:
# chem id:  D009706
# result:  OK , loadedTriples:  1935 , parsedTriples:  1935 , extra info:
# chem id:  D045424
# result:  OK , loadedTriples:  1553 , parsedTriples:  1553 , extra info:
# chem id:  D001685
# result:  OK , loadedTriples:  5277 , parsedTriples:  5277 , extra info:
# chem id:  D001697
# result:  OK , loadedTriples:  1854 , parsedTriples:  1854 , extra info:
# chem id:  D004364
# result:  OK , loadedTriples:  868 , parsedTriples:  868 , extra info:
# chem id:  D020164
# result:  OK , loadedTriples:  6938 , parsedTriples:  6938 , extra info:

# %% [markdown]
# ## Import Ontology

# %%
def run_import_disease_onto(tx):
    disease_onto_url = "http://purl.obolibrary.org/obo/doid.owl"

    #import classes, properties, rels and hierarchies
    result = tx.run("CALL n10s.onto.import.fetch($ontourl,'RDF/XML')", ontourl=disease_onto_url)
    for record in result:
        print("result: ", record["terminationStatus"], 
              ", loadedTriples: ", record["triplesLoaded"], 
              ", parsedTriples: ", record["triplesParsed"], 
              ", extra info: ", record["extraInfo"])
    
    #add extra label to classes
    result = tx.run("MATCH (c:Class) SET c:DO_Disease RETURN count(c) as classCount")
    for record in result:
        print("labels added: ", record["classCount"])
    
    #add crossreferences to MeSH
    result = tx.run("""CALL n10s.rdf.stream.fetch($ontourl,'RDF/XML', { limit : 999999}) YIELD subject, predicate, object 
              WHERE predicate = 'http://www.geneontology.org/formats/oboInOwl#hasDbXref' 
                AND object STARTS WITH 'MESH:'
              MATCH (doe:Resource { uri: subject}),
                    (mesh:Resource { uri: 'http://id.nlm.nih.gov/mesh/' + substring(object,5)})
                MERGE (doe)-[:SAME_AS_MESH_DESCRIPTOR]->(mesh)
                RETURN count(doe) as xrefItems """, ontourl=disease_onto_url)
    for record in result:
        print("#crossreferenced items: ", record["xrefItems"])

# %%
session.write_transaction(run_import_disease_onto)
# Out:
# result:  OK , loadedTriples:  39697 , parsedTriples:  222730 , extra info:
# labels added:  12593
# #crossreferenced items:  2803
